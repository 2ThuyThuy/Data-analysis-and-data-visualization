# %%
from google.colab  import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a5a08819-a7b6-4fac-b135-2a947f44886a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a5a08819-a7b6-4fac-b135-2a947f44886a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-d3142276d19b> in <module>()
#       1 from google.colab  import files
# ----> 2 uploaded = files.upload()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      44   """
#      45
# ---> 46   uploaded_files = _upload_files(multiple=True)
#      47   # Mapping from original filename to filename as saved locally.
#      48   local_filenames = dict()
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Ecommerce Purchases.csv')

# %%
df.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
#How many rows and columns are there?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
#columns 
len(df.columns)
# Out:
# 14

# %%
#rows
len(df.index)
# Out:
# 10000

# %%
#what is the average Purchase price?
df['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %%
#What were the highest and lowest purchase prices?
print("highest:",df['Purchase Price'].max())
print("lowest:",df['Purchase Price'].min())
# Out:
# highest: 99.99
# lowest: 0.0

# %%
#How many people have English 'en' as their Language of choice on the website?
len(df[df['Language'] == 'en'].index)
# Out:
# 1098

# %%
df[df['Language'] == 'en']['Language'].count()
# Out:
# 1098

# %%
#How many people have the job title of "Lawyer"?
df[df['Job'] == 'Lawyer']['Job'].count()
# Out:
# 30

# %%
#How many people made the purchase during the AM and how many people made 
#the purchase during PM?
print('PM: ',len(df[df['AM or PM'] == 'PM']))
print('AM: ',len(df[df['AM or PM'] == 'AM']))
# Out:
# PM:  5068
# AM:  4932

# %%
df['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
#What are the 5 most common Job Titles?
df['Job'].value_counts().head(5)
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
# Name: Job, dtype: int64

# %%
#Someone made a purchase that came from Lot:"90 WT", that was the Purchase Price
#for this transaction?
df[df['Lot']=='90 WT']['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %%
#What is the email of the person with the following
#Credit Card Number:4926535242672853
df[df['Credit Card'] == 4926535242672853]['Email']
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %%
#how many people have American Express as their Credit Card Provider and made 
# a purchase above $95
len(df[(df['Purchase Price']>95) & (df['CC Provider']=='American Express')].index)
# Out:
# 39

# %%
#How many people have a credit card that expires in 2025
def check_yearExp(year):
  if int(year[3:5]) == 25:
    return True
  return False

# %%
len(df[df['CC Exp Date'].apply(lambda x: check_yearExp(x))].index)
# Out:
# 1033

# %%
#What are the top 5 most popular email providers/hosts(e.g gmail.com, yahoo.com, etc)
def convert_email(email):
  id = email.index('@')
  return email[email.index('@')+1:]

# %%
df['Email'].apply(lambda x: x[x.index('@')+1:]).value_counts().head(5)
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64
